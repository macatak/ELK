# %% [markdown]
# # Elasticsearch Low-Level Python API
# ## Node operations
# ### Assumes Star Wars indices are loaded

# %%
# import
import json
from elasticsearch import Elasticsearch

# %% [markdown]
# ## Connect to Cluster

# %%
es_conn1 = Elasticsearch([{'host': '10.0.2.15', 'port': 9200}])
# print the health just because...
print(es_conn1.cluster.health())
# Out:
# {'cluster_name': 'parrot_elk', 'status': 'yellow', 'timed_out': False, 'number_of_nodes': 1, 'number_of_data_nodes': 1, 'active_primary_shards': 9, 'active_shards': 9, 'relocating_shards': 0, 'initializing_shards': 0, 'unassigned_shards': 8, 'delayed_unassigned_shards': 0, 'number_of_pending_tasks': 0, 'number_of_in_flight_fetch': 0, 'task_max_waiting_in_queue_millis': 0, 'active_shards_percent_as_number': 52.94117647058824}

# %%
# useful json print function
# json print function
def json_print(json_obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(json_obj, sort_keys=True, indent=3)
    print(text)

# %% [markdown]
# ## Node Operations

# %%
# allocations
print('base allocation : ', es_conn1.cat.allocation())
# Out:
# base allocation :  9 441.1kb 33.9gb 48gb 82gb 41 10.0.2.15 10.0.2.15 parrot
# 8                                                 UNASSIGNED

# %%
# shards
print('shards : ', es_conn1.cat.allocation(h='shards'))
# Out:
# shards :  9
# 8

# %%
# disk space available
print('% disk available : ', es_conn1.cat.allocation(h='disk.percent'))
# Out:
# % disk available :  41

# %%
# node info
# good for health monitoring
# only a small amount of info shows up by default
# run 'GET _cat/nodes?help' to see the full info list
print('es_conn3.cat.nodes: ', es_conn1.cat.nodes())
# Out:
# es_conn3.cat.nodes:  10.0.2.15 13 47 3 0.30 0.24 0.12 dim * parrot

# %%
# get the max file descriptor setting
print('max file descriptor:', es_conn1.cat.nodes(h='file_desc.max'))
# Out:
# max file descriptor: 65535

# %%
# hot threads
# need to look into what this is useful for
hot_threads = es_conn1.nodes.hot_threads()
print(hot_threads)
# Out:
# ::: {parrot}{93tVwMVdRyKf8eqHq2bF4w}{BbMK5ysKSve776-JqibczA}{10.0.2.15}{10.0.2.15:9300}{dim}
#    Hot threads at 2020-01-05T15:16:31.083Z, interval=500ms, busiestThreads=3, ignoreIdleThreads=true:

# %%
node_info = es_conn3.nodes.info()
json_print(node_info)
#print('\n type:', type(node_info))
# Out:
# {
#    "_nodes": {
#       "failed": 0,
#       "successful": 1,
#       "total": 1
#    },
#    "cluster_name": "parrot_elk",
#    "nodes": {
#       "93tVwMVdRyKf8eqHq2bF4w": {
#          "build_flavor": "oss",
#          "build_hash": "2f90bbf7b93631e52bafb59b3b049cb44ec25e96",
#          "build_type": "deb",
#          "host": "10.0.2.15",
#          "http": {
#             "bound_address": [
#                "10.0.2.15:9200"
#             ],
#             "max_content_length_in_bytes": 104857600,
#             "publish_address": "10.0.2.15:9200"
#          },
#          "ingest": {
#             "processors": [
#                {
#                   "type": "append"
#                },
#                {
#                   "type": "bytes"
#                },
#                {
#                   "type": "convert"
#                },
#                {
#                   "type": "date"
#                },
#                {
#                   "type": "date_index_name"
#                },
#                {
#                   "type": "dissect"
#                },
#                {
#                   "type": "dot_expander"
#                },
#                {
#                   "type": "drop"
#                },
#                {
#                   "type": "fail"
#                },
#                {
#                   "type": "foreach"
#                },
#                {
#                   "type": "geoip"
#                },
#                {
#                   "type": "grok"
#                },
#                {
#                   "type": "gsub"
#                },
#                {
#                   "type": "html_strip"
#                },
#                {
#                   "type": "join"
#                },
#                {
#                   "type": "json"
#                },
#                {
#                   "type": "kv"
#                },
#                {
#                   "type": "lowercase"
#                },
#                {
#                   "type": "pipeline"
#                },
#                {
#                   "type": "remove"
#                },
#                {
#                   "type": "rename"
#                },
#                {
#                   "type": "script"
#                },
#                {
#                   "type": "set"
#                },
#                {
#                   "type": "sort"
#                },
#                {
#                   "type": "split"
#                },
#                {
#                   "type": "trim"
#                },
#                {
#                   "type": "uppercase"
#                },
#                {
#                   "type": "urldecode"
#                },
#                {
#                   "type": "user_agent"
#                }
#             ]
#          },
#          "ip": "10.0.2.15",
#          "jvm": {
#             "bundled_jdk": true,
#             "gc_collectors": [
#                "ParNew",
#                "ConcurrentMarkSweep"
#             ],
#             "input_arguments": [
#                "-Xms1g",
#                "-Xmx1g",
#                "-XX:+UseConcMarkSweepGC",
#                "-XX:CMSInitiatingOccupancyFraction=75",
#                "-XX:+UseCMSInitiatingOccupancyOnly",
#                "-Des.networkaddress.cache.ttl=60",
#                "-Des.networkaddress.cache.negative.ttl=10",
#                "-XX:+AlwaysPreTouch",
#                "-Xss1m",
#                "-Djava.awt.headless=true",
#                "-Dfile.encoding=UTF-8",
#                "-Djna.nosys=true",
#                "-XX:-OmitStackTraceInFastThrow",
#                "-Dio.netty.noUnsafe=true",
#                "-Dio.netty.noKeySetOptimization=true",
#                "-Dio.netty.recycler.maxCapacityPerThread=0",
#                "-Dio.netty.allocator.numDirectArenas=0",
#                "-Dlog4j.shutdownHookEnabled=false",
#                "-Dlog4j2.disable.jmx=true",
#                "-Djava.io.tmpdir=/tmp/elasticsearch-1205100710672525252",
#                "-XX:+HeapDumpOnOutOfMemoryError",
#                "-XX:HeapDumpPath=/var/lib/elasticsearch",
#                "-XX:ErrorFile=/var/log/elasticsearch/hs_err_pid%p.log",
#                "-Xlog:gc*,gc+age=trace,safepoint:file=/var/log/elasticsearch/gc.log:utctime,pid,tags:filecount=32,filesize=64m",
#                "-Djava.locale.providers=COMPAT",
#                "-Dio.netty.allocator.type=unpooled",
#                "-XX:MaxDirectMemorySize=536870912",
#                "-Des.path.home=/usr/share/elasticsearch",
#                "-Des.path.conf=/etc/elasticsearch",
#                "-Des.distribution.flavor=oss",
#                "-Des.distribution.type=deb",
#                "-Des.bundled_jdk=true"
#             ],
#             "mem": {
#                "direct_max_in_bytes": 0,
#                "heap_init_in_bytes": 1073741824,
#                "heap_max_in_bytes": 1038876672,
#                "non_heap_init_in_bytes": 7667712,
#                "non_heap_max_in_bytes": 0
#             },
#             "memory_pools": [
#                "CodeHeap 'non-nmethods'",
#                "Metaspace",
#                "CodeHeap 'profiled nmethods'",
#                "Compressed Class Space",
#                "Par Eden Space",
#                "Par Survivor Space",
#                "CodeHeap 'non-profiled nmethods'",
#                "CMS Old Gen"
#             ],
#             "pid": 886,
#             "start_time_in_millis": 1578235365106,
#             "using_bundled_jdk": true,
#             "using_compressed_ordinary_object_pointers": "true",
#             "version": "13.0.1",
#             "vm_name": "OpenJDK 64-Bit Server VM",
#             "vm_vendor": "AdoptOpenJDK",
#             "vm_version": "13.0.1+9"
#          },
#          "modules": [
#             {
#                "classname": "org.elasticsearch.search.aggregations.matrix.MatrixAggregationPlugin",
#                "description": "Adds aggregations whose input are a list of numeric fields and output includes a matrix.",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "aggs-matrix-stats",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.analysis.common.CommonAnalysisPlugin",
#                "description": "Adds \"built in\" analyzers to Elasticsearch.",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [
#                   "lang-painless"
#                ],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "analysis-common",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.ingest.common.IngestCommonPlugin",
#                "description": "Module for ingest processors that do not require additional security permissions or have large dependencies and resources",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [
#                   "lang-painless"
#                ],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "ingest-common",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.ingest.geoip.IngestGeoIpPlugin",
#                "description": "Ingest processor that uses looksup geo data based on ip adresses using the Maxmind geo database",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "ingest-geoip",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.ingest.useragent.IngestUserAgentPlugin",
#                "description": "Ingest processor that extracts information from a user agent",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "ingest-user-agent",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.script.expression.ExpressionPlugin",
#                "description": "Lucene expressions integration for Elasticsearch",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "lang-expression",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.script.mustache.MustachePlugin",
#                "description": "Mustache scripting integration for Elasticsearch",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "lang-mustache",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.painless.PainlessPlugin",
#                "description": "An easy, safe and fast scripting language for Elasticsearch",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "lang-painless",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.index.mapper.MapperExtrasPlugin",
#                "description": "Adds advanced field mappers",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "mapper-extras",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.join.ParentJoinPlugin",
#                "description": "This module adds the support parent-child queries and aggregations",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "parent-join",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.percolator.PercolatorPlugin",
#                "description": "Percolator module adds capability to index queries and query these queries by specifying documents",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "percolator",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.index.rankeval.RankEvalPlugin",
#                "description": "The Rank Eval module adds APIs to evaluate ranking quality.",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "rank-eval",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.index.reindex.ReindexPlugin",
#                "description": "The Reindex module adds APIs to reindex from one index to another or update documents in place.",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "reindex",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.plugin.repository.url.URLRepositoryPlugin",
#                "description": "Module for URL repository",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "repository-url",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.systemd.SystemdPlugin",
#                "description": "Integrates Elasticsearch with systemd",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "systemd",
#                "version": "7.4.2"
#             },
#             {
#                "classname": "org.elasticsearch.transport.Netty4Plugin",
#                "description": "Netty 4 based transport implementation",
#                "elasticsearch_version": "7.4.2",
#                "extended_plugins": [],
#                "has_native_controller": false,
#                "java_version": "1.8",
#                "name": "transport-netty4",
#                "version": "7.4.2"
#             }
#          ],
#          "name": "parrot",
#          "os": {
#             "allocated_processors": 4,
#             "arch": "amd64",
#             "available_processors": 4,
#             "name": "Linux",
#             "pretty_name": "Parrot GNU/Linux 4.7",
#             "refresh_interval_in_millis": 1000,
#             "version": "5.3.0-3parrot3-amd64"
#          },
#          "plugins": [],
#          "process": {
#             "id": 886,
#             "mlockall": false,
#             "refresh_interval_in_millis": 1000
#          },
#          "roles": [
#             "ingest",
#             "master",
#             "data"
#          ],
#          "settings": {
#             "client": {
#                "type": "node"
#             },
#             "cluster": {
#                "name": "parrot_elk"
#             },
#             "discovery": {
#                "type": "single-node"
#             },
#             "http": {
#                "port": "9200",
#                "type": {
#                   "default": "netty4"
#                }
#             },
#             "network": {
#                "host": "10.0.2.15"
#             },
#             "node": {
#                "name": "parrot",
#                "pidfile": "/var/run/elasticsearch/elasticsearch.pid"
#             },
#             "path": {
#                "data": [
#                   "/var/lib/elasticsearch"
#                ],
#                "home": "/usr/share/elasticsearch",
#                "logs": "/var/log/elasticsearch"
#             },
#             "transport": {
#                "type": {
#                   "default": "netty4"
#                }
#             }
#          },
#          "thread_pool": {
#             "analyze": {
#                "queue_size": 16,
#                "size": 1,
#                "type": "fixed"
#             },
#             "fetch_shard_started": {
#                "core": 1,
#                "keep_alive": "5m",
#                "max": 8,
#                "queue_size": -1,
#                "type": "scaling"
#             },
#             "fetch_shard_store": {
#                "core": 1,
#                "keep_alive": "5m",
#                "max": 8,
#                "queue_size": -1,
#                "type": "scaling"
#             },
#             "flush": {
#                "core": 1,
#                "keep_alive": "5m",
#                "max": 2,
#                "queue_size": -1,
#                "type": "scaling"
#             },
#             "force_merge": {
#                "queue_size": -1,
#                "size": 1,
#                "type": "fixed"
#             },
#             "generic": {
#                "core": 4,
#                "keep_alive": "30s",
#                "max": 128,
#                "queue_size": -1,
#                "type": "scaling"
#             },
#             "get": {
#                "queue_size": 1000,
#                "size": 4,
#                "type": "fixed"
#             },
#             "listener": {
#                "queue_size": -1,
#                "size": 2,
#                "type": "fixed"
#             },
#             "management": {
#                "core": 1,
#                "keep_alive": "5m",
#                "max": 5,
#                "queue_size": -1,
#                "type": "scaling"
#             },
#             "refresh": {
#                "core": 1,
#                "keep_alive": "5m",
#                "max": 2,
#                "queue_size": -1,
#                "type": "scaling"
#             },
#             "search": {
#                "queue_size": 1000,
#                "size": 7,
#                "type": "fixed_auto_queue_size"
#             },
#             "search_throttled": {
#                "queue_size": 100,
#                "size": 1,
#                "type": "fixed_auto_queue_size"
#             },
#             "snapshot": {
#                "core": 1,
#                "keep_alive": "5m",
#                "max": 2,
#                "queue_size": -1,
#                "type": "scaling"
#             },
#             "warmer": {
#                "core": 1,
#                "keep_alive": "5m",
#                "max": 2,
#                "queue_size": -1,
#                "type": "scaling"
#             },
#             "write": {
#                "queue_size": 200,
#                "size": 4,
#                "type": "fixed"
#             }
#          },
#          "total_indexing_buffer": 103887667,
#          "transport": {
#             "bound_address": [
#                "10.0.2.15:9300"
#             ],
#             "profiles": {},
#             "publish_address": "10.0.2.15:9300"
#          },
#          "transport_address": "10.0.2.15:9300",
#          "version": "7.4.2"
#       }
#    }
# }

# %%
# node stats
json_print(es_conn1.nodes.stats())
# Out:
# {
#    "_nodes": {
#       "failed": 0,
#       "successful": 1,
#       "total": 1
#    },
#    "cluster_name": "parrot_elk",
#    "nodes": {
#       "93tVwMVdRyKf8eqHq2bF4w": {
#          "adaptive_selection": {
#             "93tVwMVdRyKf8eqHq2bF4w": {
#                "avg_queue_size": 0,
#                "avg_response_time_ns": 622681,
#                "avg_service_time_ns": 8521356,
#                "outgoing_searches": 0,
#                "rank": "0.6"
#             }
#          },
#          "breakers": {
#             "accounting": {
#                "estimated_size": "176.6kb",
#                "estimated_size_in_bytes": 180844,
#                "limit_size": "990.7mb",
#                "limit_size_in_bytes": 1038876672,
#                "overhead": 1.0,
#                "tripped": 0
#             },
#             "fielddata": {
#                "estimated_size": "0b",
#                "estimated_size_in_bytes": 0,
#                "limit_size": "396.2mb",
#                "limit_size_in_bytes": 415550668,
#                "overhead": 1.03,
#                "tripped": 0
#             },
#             "in_flight_requests": {
#                "estimated_size": "0b",
#                "estimated_size_in_bytes": 0,
#                "limit_size": "990.7mb",
#                "limit_size_in_bytes": 1038876672,
#                "overhead": 2.0,
#                "tripped": 0
#             },
#             "parent": {
#                "estimated_size": "160.1mb",
#                "estimated_size_in_bytes": 167936672,
#                "limit_size": "941.2mb",
#                "limit_size_in_bytes": 986932838,
#                "overhead": 1.0,
#                "tripped": 0
#             },
#             "request": {
#                "estimated_size": "0b",
#                "estimated_size_in_bytes": 0,
#                "limit_size": "594.4mb",
#                "limit_size_in_bytes": 623326003,
#                "overhead": 1.0,
#                "tripped": 0
#             }
#          },
#          "discovery": {
#             "cluster_state_queue": {
#                "committed": 0,
#                "pending": 0,
#                "total": 0
#             },
#             "published_cluster_states": {
#                "compatible_diffs": 19,
#                "full_states": 2,
#                "incompatible_diffs": 0
#             }
#          },
#          "fs": {
#             "data": [
#                {
#                   "available_in_bytes": 51595522048,
#                   "free_in_bytes": 56112263168,
#                   "mount": "/ (/dev/sda1)",
#                   "path": "/var/lib/elasticsearch/nodes/0",
#                   "total_in_bytes": 88049033216,
#                   "type": "ext4"
#                }
#             ],
#             "io_stats": {
#                "devices": [
#                   {
#                      "device_name": "sda1",
#                      "operations": 26944,
#                      "read_kilobytes": 454508,
#                      "read_operations": 21724,
#                      "write_kilobytes": 121608,
#                      "write_operations": 5220
#                   }
#                ],
#                "total": {
#                   "operations": 26944,
#                   "read_kilobytes": 454508,
#                   "read_operations": 21724,
#                   "write_kilobytes": 121608,
#                   "write_operations": 5220
#                }
#             },
#             "least_usage_estimate": {
#                "available_in_bytes": 51595624448,
#                "path": "/var/lib/elasticsearch/nodes/0",
#                "total_in_bytes": 88049033216,
#                "used_disk_percent": 41.40125954429651
#             },
#             "most_usage_estimate": {
#                "available_in_bytes": 51595624448,
#                "path": "/var/lib/elasticsearch/nodes/0",
#                "total_in_bytes": 88049033216,
#                "used_disk_percent": 41.40125954429651
#             },
#             "timestamp": 1578237521452,
#             "total": {
#                "available_in_bytes": 51595522048,
#                "free_in_bytes": 56112263168,
#                "total_in_bytes": 88049033216
#             }
#          },
#          "host": "10.0.2.15",
#          "http": {
#             "current_open": 7,
#             "total_opened": 7
#          },
#          "indices": {
#             "completion": {
#                "size_in_bytes": 0
#             },
#             "docs": {
#                "count": 281,
#                "deleted": 1
#             },
#             "fielddata": {
#                "evictions": 0,
#                "memory_size_in_bytes": 0
#             },
#             "flush": {
#                "periodic": 0,
#                "total": 11,
#                "total_time_in_millis": 151
#             },
#             "get": {
#                "current": 0,
#                "exists_time_in_millis": 5,
#                "exists_total": 1,
#                "missing_time_in_millis": 0,
#                "missing_total": 0,
#                "time_in_millis": 5,
#                "total": 1
#             },
#             "indexing": {
#                "delete_current": 0,
#                "delete_time_in_millis": 0,
#                "delete_total": 0,
#                "index_current": 0,
#                "index_failed": 0,
#                "index_time_in_millis": 0,
#                "index_total": 0,
#                "is_throttled": false,
#                "noop_update_total": 0,
#                "throttle_time_in_millis": 0
#             },
#             "merges": {
#                "current": 0,
#                "current_docs": 0,
#                "current_size_in_bytes": 0,
#                "total": 0,
#                "total_auto_throttle_in_bytes": 230686720,
#                "total_docs": 0,
#                "total_size_in_bytes": 0,
#                "total_stopped_time_in_millis": 0,
#                "total_throttled_time_in_millis": 0,
#                "total_time_in_millis": 0
#             },
#             "query_cache": {
#                "cache_count": 0,
#                "cache_size": 0,
#                "evictions": 0,
#                "hit_count": 0,
#                "memory_size_in_bytes": 0,
#                "miss_count": 0,
#                "total_count": 0
#             },
#             "recovery": {
#                "current_as_source": 0,
#                "current_as_target": 0,
#                "throttle_time_in_millis": 0
#             },
#             "refresh": {
#                "external_total": 24,
#                "external_total_time_in_millis": 15,
#                "listeners": 0,
#                "total": 26,
#                "total_time_in_millis": 13
#             },
#             "request_cache": {
#                "evictions": 0,
#                "hit_count": 12,
#                "memory_size_in_bytes": 6646,
#                "miss_count": 10
#             },
#             "search": {
#                "fetch_current": 0,
#                "fetch_time_in_millis": 2,
#                "fetch_total": 4,
#                "open_contexts": 0,
#                "query_current": 0,
#                "query_time_in_millis": 25,
#                "query_total": 22,
#                "scroll_current": 0,
#                "scroll_time_in_millis": 0,
#                "scroll_total": 0,
#                "suggest_current": 0,
#                "suggest_time_in_millis": 0,
#                "suggest_total": 0
#             },
#             "segments": {
#                "count": 23,
#                "doc_values_memory_in_bytes": 14324,
#                "file_sizes": {},
#                "fixed_bit_set_memory_in_bytes": 48,
#                "index_writer_memory_in_bytes": 0,
#                "max_unsafe_auto_id_timestamp": -1,
#                "memory_in_bytes": 180844,
#                "norms_memory_in_bytes": 17088,
#                "points_memory_in_bytes": 126,
#                "stored_fields_memory_in_bytes": 7176,
#                "term_vectors_memory_in_bytes": 0,
#                "terms_memory_in_bytes": 142130,
#                "version_map_memory_in_bytes": 0
#             },
#             "store": {
#                "size_in_bytes": 451729
#             },
#             "translog": {
#                "earliest_last_modified_age": 0,
#                "operations": 0,
#                "size_in_bytes": 3135,
#                "uncommitted_operations": 0,
#                "uncommitted_size_in_bytes": 3025
#             },
#             "warmer": {
#                "current": 0,
#                "total": 10,
#                "total_time_in_millis": 11
#             }
#          },
#          "ingest": {
#             "pipelines": {},
#             "total": {
#                "count": 0,
#                "current": 0,
#                "failed": 0,
#                "time_in_millis": 0
#             }
#          },
#          "ip": "10.0.2.15:9300",
#          "jvm": {
#             "buffer_pools": {
#                "direct": {
#                   "count": 26,
#                   "total_capacity_in_bytes": 7391749,
#                   "used_in_bytes": 7391750
#                },
#                "mapped": {
#                   "count": 45,
#                   "total_capacity_in_bytes": 333373,
#                   "used_in_bytes": 333373
#                }
#             },
#             "classes": {
#                "current_loaded_count": 12984,
#                "total_loaded_count": 12984,
#                "total_unloaded_count": 0
#             },
#             "gc": {
#                "collectors": {
#                   "old": {
#                      "collection_count": 2,
#                      "collection_time_in_millis": 98
#                   },
#                   "young": {
#                      "collection_count": 4,
#                      "collection_time_in_millis": 163
#                   }
#                }
#             },
#             "mem": {
#                "heap_committed_in_bytes": 1038876672,
#                "heap_max_in_bytes": 1038876672,
#                "heap_used_in_bytes": 167936672,
#                "heap_used_percent": 16,
#                "non_heap_committed_in_bytes": 100229120,
#                "non_heap_used_in_bytes": 92139832,
#                "pools": {
#                   "old": {
#                      "max_in_bytes": 724828160,
#                      "peak_max_in_bytes": 724828160,
#                      "peak_used_in_bytes": 31621184,
#                      "used_in_bytes": 31562944
#                   },
#                   "survivor": {
#                      "max_in_bytes": 34865152,
#                      "peak_max_in_bytes": 34865152,
#                      "peak_used_in_bytes": 30302896,
#                      "used_in_bytes": 26186904
#                   },
#                   "young": {
#                      "max_in_bytes": 279183360,
#                      "peak_max_in_bytes": 279183360,
#                      "peak_used_in_bytes": 279183360,
#                      "used_in_bytes": 110186824
#                   }
#                }
#             },
#             "threads": {
#                "count": 45,
#                "peak_count": 45
#             },
#             "timestamp": 1578237521452,
#             "uptime_in_millis": 2156423
#          },
#          "name": "parrot",
#          "os": {
#             "cgroup": {
#                "cpu": {
#                   "cfs_period_micros": 100000,
#                   "cfs_quota_micros": -1,
#                   "control_group": "/system.slice/elasticsearch.service",
#                   "stat": {
#                      "number_of_elapsed_periods": 0,
#                      "number_of_times_throttled": 0,
#                      "time_throttled_nanos": 0
#                   }
#                },
#                "cpuacct": {
#                   "control_group": "/system.slice/elasticsearch.service",
#                   "usage_nanos": 45632158636
#                },
#                "memory": {
#                   "control_group": "/system.slice/elasticsearch.service",
#                   "limit_in_bytes": "9223372036854771712",
#                   "usage_in_bytes": "1428389888"
#                }
#             },
#             "cpu": {
#                "load_average": {
#                   "15m": 0.15,
#                   "1m": 0.47,
#                   "5m": 0.28
#                },
#                "percent": 5
#             },
#             "mem": {
#                "free_in_bytes": 4340756480,
#                "free_percent": 52,
#                "total_in_bytes": 8353185792,
#                "used_in_bytes": 4012429312,
#                "used_percent": 48
#             },
#             "swap": {
#                "free_in_bytes": 17372803072,
#                "total_in_bytes": 17372803072,
#                "used_in_bytes": 0
#             },
#             "timestamp": 1578237521452
#          },
#          "process": {
#             "cpu": {
#                "percent": 0,
#                "total_in_millis": 44700
#             },
#             "max_file_descriptors": 65535,
#             "mem": {
#                "total_virtual_in_bytes": 4873646080
#             },
#             "open_file_descriptors": 255,
#             "timestamp": 1578237521452
#          },
#          "roles": [
#             "ingest",
#             "master",
#             "data"
#          ],
#          "script": {
#             "cache_evictions": 0,
#             "compilation_limit_triggered": 0,
#             "compilations": 0
#          },
#          "thread_pool": {
#             "analyze": {
#                "active": 0,
#                "completed": 0,
#                "largest": 0,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 0
#             },
#             "fetch_shard_started": {
#                "active": 0,
#                "completed": 11,
#                "largest": 8,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 1
#             },
#             "fetch_shard_store": {
#                "active": 0,
#                "completed": 0,
#                "largest": 0,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 0
#             },
#             "flush": {
#                "active": 0,
#                "completed": 11,
#                "largest": 2,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 2
#             },
#             "force_merge": {
#                "active": 0,
#                "completed": 1,
#                "largest": 1,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 1
#             },
#             "generic": {
#                "active": 0,
#                "completed": 1003,
#                "largest": 6,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 6
#             },
#             "get": {
#                "active": 0,
#                "completed": 1,
#                "largest": 1,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 1
#             },
#             "listener": {
#                "active": 0,
#                "completed": 0,
#                "largest": 0,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 0
#             },
#             "management": {
#                "active": 1,
#                "completed": 2451,
#                "largest": 5,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 5
#             },
#             "refresh": {
#                "active": 0,
#                "completed": 19245,
#                "largest": 2,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 2
#             },
#             "search": {
#                "active": 0,
#                "completed": 28,
#                "largest": 7,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 7
#             },
#             "search_throttled": {
#                "active": 0,
#                "completed": 0,
#                "largest": 0,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 0
#             },
#             "snapshot": {
#                "active": 0,
#                "completed": 0,
#                "largest": 0,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 0
#             },
#             "warmer": {
#                "active": 0,
#                "completed": 1,
#                "largest": 1,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 1
#             },
#             "write": {
#                "active": 0,
#                "completed": 0,
#                "largest": 0,
#                "queue": 0,
#                "rejected": 0,
#                "threads": 0
#             }
#          },
#          "timestamp": 1578237521448,
#          "transport": {
#             "rx_count": 0,
#             "rx_size_in_bytes": 0,
#             "server_open": 0,
#             "tx_count": 0,
#             "tx_size_in_bytes": 0
#          },
#          "transport_address": "10.0.2.15:9300"
#       }
#    }
# }

# %%
node_usage = es_conn3.nodes.usage()
json_print(node_usage)
# Out:
# {
#    "_nodes": {
#       "failed": 0,
#       "successful": 1,
#       "total": 1
#    },
#    "cluster_name": "parrot_elk",
#    "nodes": {
#       "93tVwMVdRyKf8eqHq2bF4w": {
#          "rest_actions": {
#             "cat_allocation_action": 6,
#             "cat_count_action": 5,
#             "cat_health_action": 2,
#             "cat_indices_action": 5,
#             "cat_nodes_action": 2,
#             "close_index_action": 1,
#             "cluster_allocation_explain_action": 1,
#             "cluster_get_settings_action": 2,
#             "cluster_health_action": 5,
#             "cluster_state_action": 1,
#             "cluster_stats_action": 1,
#             "count_action": 1,
#             "create_index_action": 1,
#             "delete_index_action": 1,
#             "document_get_action": 1,
#             "force_merge_action": 1,
#             "get_indices_action": 7,
#             "indices_segments_action": 2,
#             "indices_shard_stores_action": 1,
#             "indices_stats_action": 1,
#             "main_action": 1,
#             "nodes_hot_threads_action": 6,
#             "nodes_info_action": 875,
#             "nodes_stats_action": 2,
#             "nodes_usage_action": 1,
#             "open_index_action": 1,
#             "refresh_action": 1
#          },
#          "since": 1578235370197,
#          "timestamp": 1578237567897
#       }
#    }
# }

# %%
# no real difference from above
json_print(es_conn3.nodes.usage(human=True))
# Out:
# {
#    "_nodes": {
#       "failed": 0,
#       "successful": 1,
#       "total": 1
#    },
#    "cluster_name": "parrot_elk",
#    "nodes": {
#       "93tVwMVdRyKf8eqHq2bF4w": {
#          "rest_actions": {
#             "cat_allocation_action": 6,
#             "cat_count_action": 5,
#             "cat_health_action": 2,
#             "cat_indices_action": 5,
#             "cat_nodes_action": 2,
#             "close_index_action": 1,
#             "cluster_allocation_explain_action": 1,
#             "cluster_get_settings_action": 2,
#             "cluster_health_action": 5,
#             "cluster_state_action": 1,
#             "cluster_stats_action": 1,
#             "count_action": 1,
#             "create_index_action": 1,
#             "delete_index_action": 1,
#             "document_get_action": 1,
#             "force_merge_action": 1,
#             "get_indices_action": 7,
#             "indices_segments_action": 2,
#             "indices_shard_stores_action": 1,
#             "indices_stats_action": 1,
#             "main_action": 1,
#             "nodes_hot_threads_action": 6,
#             "nodes_info_action": 892,
#             "nodes_stats_action": 2,
#             "nodes_usage_action": 2,
#             "open_index_action": 1,
#             "refresh_action": 1
#          },
#          "since": 1578235370197,
#          "timestamp": 1578237609970
#       }
#    }
# }
